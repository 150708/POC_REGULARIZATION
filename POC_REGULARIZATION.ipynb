# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-c34d32b6-50af-4760-a671-e6781c1a0063" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c34d32b6-50af-4760-a671-e6781c1a0063">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('insurance.csv')

# %%
#Data Preprocessing
#EDA
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.head(20)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.tail(13)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1325   61    male  33.535         0     no  northeast  13143.33665
# 1326   42  female  32.870         0     no  northeast   7050.02130
# 1327   51    male  30.030         1     no  southeast   9377.90470
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
df.iloc[1050:1100]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1050   44  female  36.955         1     no  northwest   8023.13545
# 1051   64    male  26.410         0     no  northeast  14394.55790
# 1052   49    male  29.830         1     no  northeast   9288.02670
# 1053   47    male  29.800         3    yes  southwest  25309.48900
# 1054   27  female  21.470         0     no  northwest   3353.47030
# 1055   55    male  27.645         0     no  northwest  10594.50155
# 1056   48  female  28.900         0     no  southwest   8277.52300
# 1057   45  female  31.790         0     no  southeast  17929.30337
# 1058   24  female  39.490         0     no  southeast   2480.97910
# 1059   32    male  33.820         1     no  northwest   4462.72180
# 1060   24    male  32.010         0     no  southeast   1981.58190
# 1061   57    male  27.940         1     no  southeast  11554.22360
# 1062   59    male  41.140         1    yes  southeast  48970.24760
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Data cleaning --no data loss

# %%
#Label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
#x,y split

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
#train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 34)

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 1099   25    0  33.990         1       0       2
# 1214   27    0  31.255         1       0       1
# 257    38    0  40.150         0       0       2
# 66     61    0  39.100         2       0       3
# 931    39    0  32.500         1       0       3
# ...   ...  ...     ...       ...     ...     ...
# 453    20    1  29.735         0       0       1
# 324    29    1  27.200         0       0       3
# 1109   45    1  20.350         3       0       2
# 490    19    0  32.900         0       0       3
# 1146   60    1  32.800         0       1       3
#
# [936 rows x 6 columns]

# %%
y_train
# Out:
# 1099     3227.12110
# 1214     3956.07145
# 257      5400.98050
# 66      14235.07200
# 931      6238.29800
#            ...
# 453      1769.53165
# 324      2866.09100
# 1109     8605.36150
# 490      1748.77400
# 1146    52590.82939
# Name: charges, Length: 936, dtype: float64

# %%
#model building
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(x_test)

# %%
#evualation metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
lrmse = np.log(rmse)
r2 = r2_score(y_test, y_pred)

# %%
print("mae",mae)
print("mse",mse)
print("rmse",rmse)
print("lrmse",lrmse)
print("score",r2)
# Out:
# mae 8093.2429734065945
# mse 159762031.45300034
# rmse 12639.70060772803
# lrmse 9.444597981322863
# score -0.1328310524801597

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(y_test - y_pred)
residuals = y_test - y_pred
# Out:
# <ipython-input-29-07b19a9e1893>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test - y_pred)

# %%
residuals = y_test - y_pred

plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, color='blue', alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)  # Add a horizontal line at residual = 0
plt.title('Residuals vs Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Actual - Predicted)')
plt.grid(True)

plt.show()

# %%
#outlier detection
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
import seaborn as sns

# %%
df1 = df.copy()

# %%
sns.boxplot(df1['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(df1['bmi'])
# Out:
# <Axes: ylabel='bmi'>

# %%
sns.boxplot(df1['region'])
# Out:
# <Axes: ylabel='region'>

# %%
sns.boxplot(df1['charges'])
# Out:
# <Axes: ylabel='charges'>

# %%
#choosing charges
q1 = df1['charges'].quantile(0.25)
q3 = df1['charges'].quantile(0.75)

# %%
IQR = q3 - q1

# %%
lower = q1 - 1.5*IQR
upper = q3 + 1.5*IQR

# %%
lower_array = np.where(df1['charges'] < lower)[0]
upper_array = np.where(df1['charges'] > upper)[0]

# %%
df1.drop(index = lower_array,inplace = True,errors = 'ignore')
df1.drop(index = upper_array,inplace = True,errors = 'ignore')

# %%
df1
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1199 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %%
print((df1< q1-1.5*IQR) | (df1>q3 + 1.5*IQR))
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1199 rows x 7 columns]

# %%
#x,y split
x = df1.iloc[:,:-1]
y = df1.iloc[:,-1]

# %%
#train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 44)

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 1110   54    0  32.300         1       0       0
# 632    29    0  35.530         0       0       2
# 98     56    1  19.950         0       1       0
# 202    60    0  24.035         0       0       1
# 0      19    0  27.900         0       1       3
# ...   ...  ...     ...       ...     ...     ...
# 99     38    1  19.300         0       1       3
# 112    37    1  30.800         0       0       3
# 638    39    1  26.410         0       1       0
# 1336   21    0  25.800         0       0       3
# 839    59    0  31.350         0       0       1
#
# [959 rows x 6 columns]

# %%
y_train
# Out:
# 1110    11512.40500
# 632      3366.66970
# 98      22412.64850
# 202     13012.20865
# 0       16884.92400
#            ...
# 99      15820.69900
# 112      4646.75900
# 638     20149.32290
# 1336     2007.94500
# 839     12622.17950
# Name: charges, Length: 959, dtype: float64

# %%
#model building
from sklearn.svm import SVR
svr = SVR()
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(x_test)

# %%
#evualation metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
lrmse = np.log(rmse)
r2 = r2_score(y_test, y_pred)

# %%
print("mae",mae)
print("mse",mse)
print("rmse",rmse)
print("lrmse",lrmse)
print("score",r2)
# Out:
# mae 5346.101807990651
# mse 52495178.39763991
# rmse 7245.35564328211
# lrmse 8.888115941649671
# score -0.03861380079561916

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
sns.distplot(y_test - y_pred)
# Out:
# <ipython-input-56-99fbca297671>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test - y_pred)
# <Axes: xlabel='charges', ylabel='Density'>

# %%
residuals = y_test - y_pred

plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, color='blue', alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)  # Add a horizontal line at residual = 0
plt.title('Residuals vs Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Actual - Predicted)')
plt.grid(True)

plt.show()

# %%
#ridge regression
df2 = df.copy()

# %%
x = df2.iloc[:,:-1]
y = df2.iloc[:,-1]

# %%
#train_test_split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 14)

# %%
#ridge regression
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 1)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred = ridge.predict(x_test)

# %%
#evualation metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
lrmse = np.log(rmse)
r2 = r2_score(y_test, y_pred)

# %%
print("mae",mae)
print("mse",mse)
print("rmse",rmse)
print("lrmse",lrmse)
print("r2",r2)
# Out:
# mae 4319.264720848135
# mse 36313267.85466497
# rmse 6026.049108218831
# lrmse 8.70384686904616
# r2 0.7477792440409896

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
sns.distplot(y_test - y_pred)
# Out:
# <ipython-input-66-99fbca297671>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test - y_pred)
# <Axes: xlabel='charges', ylabel='Density'>

# %%
residuals = y_test - y_pred

plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, color='blue', alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)  # Add a horizontal line at residual = 0
plt.title('Residuals vs Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Actual - Predicted)')
plt.grid(True)

plt.show()
